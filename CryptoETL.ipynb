# %%
import csv
import pandas as pd

# %%
# import csv files
csvfile = "./Resources/reddit_wsb.csv"
wsb_csv = pd.read_csv(csvfile)
wsb_csv.head()
# Out:
#                                                title  score      id  \
# 0  It's not about the money, it's about sending a...     55  l6ulcx
# 1  Math Professor Scott Steiner says the numbers ...    110  l6uibd
# 2                                    Exit the system      0  l6uhhn
# 3  NEW SEC FILING FOR GME! CAN SOMEONE LESS RETAR...     29  l6ugk6
# 4  Not to distract from GME, just thought our AMC...     71  l6ufgy
#
#                                                  url  comms_num       created  \
# 0                    https://v.redd.it/6j75regs72e61          6  1.611863e+09
# 1                    https://v.redd.it/ah50lyny62e61         23  1.611862e+09
# 2  https://www.reddit.com/r/wallstreetbets/commen...         47  1.611862e+09
# 3  https://sec.report/Document/0001193125-21-019848/         74  1.611862e+09
# 4                https://i.redd.it/4h2sukb662e61.jpg        156  1.611862e+09
#
#                                                 body            timestamp
# 0                                                NaN  2021-01-28 21:37:41
# 1                                                NaN  2021-01-28 21:32:10
# 2  The CEO of NASDAQ pushed to halt trading “to g...  2021-01-28 21:30:35
# 3                                                NaN  2021-01-28 21:28:57
# 4                                                NaN  2021-01-28 21:26:56

# %%
wsb_csv['body'] = wsb_csv['body'].fillna("")

# %%
wsb_csv.columns
wsb_csv['title_body'] = wsb_csv['title'] + wsb_csv['body']
wsb_csv.drop(columns=['score', 'id','url','comms_num','created', 'title', 'body'], inplace=True)

# %%
wsb_csv['title_body'] = wsb_csv['title_body'].str.upper()

# %%
ticker_list = {'GME': ['GAMESTOP', 'GME'], 'AMC': ['AMC'], 'CLOV': ['CLOV'], 'SNDL': ['SNDL']}

for ticker, stock_names in ticker_list.items():
    for name in stock_names:
        wsb_csv[ticker] = wsb_csv['title_body'].str.contains(name).astype(int)

# %%
wsb_csv.head(20)
# Out:
#      timestamp                                         title_body  GME  AMC  \
# 0   2021-01-28  IT'S NOT ABOUT THE MONEY, IT'S ABOUT SENDING A...    0    0
# 1   2021-01-28  MATH PROFESSOR SCOTT STEINER SAYS THE NUMBERS ...    0    0
# 2   2021-01-28  EXIT THE SYSTEMTHE CEO OF NASDAQ PUSHED TO HAL...    1    0
# 3   2021-01-28  NEW SEC FILING FOR GME! CAN SOMEONE LESS RETAR...    1    0
# 4   2021-01-28  NOT TO DISTRACT FROM GME, JUST THOUGHT OUR AMC...    1    1
# 5   2021-01-28                                WE BREAKING THROUGH    0    0
# 6   2021-01-28  SHORT STOCK DOESN'T HAVE AN EXPIRATION DATEHED...    1    0
# 7   2021-01-28  THIS IS THE MOMENTLIFE ISN'T FAIR. MY MOTHER A...    1    0
# 8   2021-01-28  CURRENTLY HOLDING AMC AND NOK - IS IT RETARDED...    1    1
# 9   2021-01-28  I HAVE NOTHING TO SAY BUT BRUH I AM SPEECHLESS...    0    0
# 10  2021-01-28  WE NEED TO KEEP THIS MOVEMENT GOING, WE ALL CA...    1    1
# 11  2021-01-28                 GME PREMARKET 🍁 MUSK APPROVED 🎮🛑💎✋    1    0
# 12  2021-01-28  ONCE YOU'RE DONE WITH GME - $AG AND $SLV, THE ...    1    0
# 13  2021-01-28  $GME PRICE HAS NOTHING TO DO WITH FUNDAMENTALS...    1    0
# 14  2021-01-28                             I LOVE YOU RETARDS!!!!    0    0
# 15  2021-01-28                       420 WASN’T A MEME. GME 🚀 🚀 🚀    1    0
# 16  2021-01-28                        TO THE MASS RELAYS & BEYOND    0    0
# 17  2021-01-28  I COME BACK TO YOU NOW... AT THE TURN OF THE T...    0    0
# 18  2021-01-28   9 WORDS BROUGHT TO YOU BY THE FUCKERS AT THE SEC    0    0
# 19  2021-01-28  DAILY DISCUSSION THREAD FOR JANUARY 28, 2021YO...    0    0
#
#     CLOV   weekday  SNDL
# 0      0  Thursday     0
# 1      0  Thursday     0
# 2      0  Thursday     0
# 3      0  Thursday     0
# 4      0  Thursday     0
# 5      0  Thursday     0
# 6      0  Thursday     0
# 7      0  Thursday     0
# 8      0  Thursday     0
# 9      0  Thursday     0
# 10     0  Thursday     0
# 11     0  Thursday     0
# 12     0  Thursday     0
# 13     0  Thursday     0
# 14     0  Thursday     0
# 15     0  Thursday     0
# 16     0  Thursday     0
# 17     0  Thursday     0
# 18     0  Thursday     0
# 19     0  Thursday     0

# %%
wsb_csv['timestamp'] = pd.to_datetime(wsb_csv['timestamp']).dt.date
wsb_csv['weekday'] = pd.to_datetime(wsb_csv['timestamp']).dt.day_name()

# %%
new_df = wsb_csv.groupby(["timestamp"]).sum()["SNDL"].sort_values(ascending=False)
new_df
# Out:
# timestamp
# 2021-01-29    224
# 2021-01-28     20
# 2021-02-12     15
# 2021-02-11     14
# 2021-01-30      8
#              ...
# 2021-04-02      0
# 2021-03-31      0
# 2021-03-30      0
# 2021-03-28      0
# 2021-06-01      0
# Name: SNDL, Length: 123, dtype: int64
